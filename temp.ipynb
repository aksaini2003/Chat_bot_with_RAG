# %%
from ddgs import DDGS
search=DDGS() 
output=search.text('global warmimg',max_results=5,region='us-en')

# %%
output
# Out:
# [{'title': 'Global warming potential',
#   'href': 'https://en.wikipedia.org/wiki/Global_warming_potential',
# ...
